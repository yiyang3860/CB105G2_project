# %%
'''

用戶菜單功能介紹

    用戶能透過點擊菜單，進行我方希冀之業務功能。
    
流程
    準備菜單的圖面設定檔
    讀取安全設定檔上的參數
    將菜單設定檔傳給Line
    對Line上傳菜單照片
    檢視現有的菜單
    將菜單與用戶做綁定
    將菜單與用戶解除綁定
    刪除菜單

'''
# Out:
# '\n\n用戶菜單功能介紹\n\n    用戶能透過點擊菜單，進行我方希冀之業務功能。\n    \n流程\n    準備菜單的圖面設定檔\n    讀取安全設定檔上的參數\n    將菜單設定檔傳給Line\n    對Line上傳菜單照片\n    檢視現有的菜單\n    將菜單與用戶做綁定\n    將菜單與用戶解除綁定\n    刪除菜單\n\n'

# %%
'''
菜單設定檔

    設定圖面大小、按鍵名與功能
    
'''

menuRawData="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "圖文選單 1",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 0,
        "y": 0,
        "width": 839,
        "height": 818
      },
      "action": {
        "type": "uri",
        "uri": "line://app/1562278840-lPQGXbQ1"
        }
    },
    {
      "bounds": {
        "x": 835,
        "y": 4,
        "width": 830,
        "height": 818
      },
      "action": {
        "type": "message",
        "text": "台北總店：101頂樓\\n 台中總店： 火力發電廠\\n 高雄總店：發大財"
      }
    },
    {
      "bounds": {
        "x": 1669,
        "y": 0,
        "width": 831,
        "height": 823
      },
      "action": {
        "type": "postback",
        "text": "[::text:]onsale",
        "data": "tag=onsale"
      }
    },
    {
      "bounds": {
        "x": 4,
        "y": 822,
        "width": 834,
        "height": 816
      },
      "action": {
        "type": "uri",
        "uri": "line://app/1562278840-mqAaVgA8"
      }
    },
    {
      "bounds": {
        "x": 839,
        "y": 818,
        "width": 826,
        "height": 817
      },
      "action": {
        "type": "postback",
        "text": "[::text:]contact",
        "data": "/contact_us"
      }
    },
    {
      "bounds": {
        "x": 1700,
        "y": 858,
        "width": 800,
        "height": 810
      },
      "action": {
        "type": "postback",
        "text": "[::text:]more",
        "data": "[::text:]more"
      }
    }
  ]
}
"""

# %%
'''
菜單設定檔

    設定圖面大小、按鍵名與功能
    
'''

Signup = """
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "圖文選單 3",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 263,
        "y": 258,
        "width": 2063,
        "height": 801
      },
      "action": {
        "type": "postback",
        "text": "加入會員",
        "data": "tag=adduser"
      }
    }
  ]
}
"""

# %%
'''
菜單設定檔

    設定圖面大小、按鍵名與功能
    
'''

menuRawData2="""
{
  "size": {
    "width": 2500,
    "height": 1686
  },
  "selected": true,
  "name": "圖文選單 1",
  "chatBarText": "查看更多資訊",
  "areas": [
    {
      "bounds": {
        "x": 0,
        "y": 0,
        "width": 839,
        "height": 818
      },
      "action": {
        "type": "postback",
        "text": "會員資料",
        "data": "tag=userprofile"
        }
    },
    {
      "bounds": {
        "x": 835,
        "y": 4,
        "width": 830,
        "height": 818
      },
      "action": {
        "type": "postback",
        "text": "門市資訊",
        "data": "tag=shopinfo"
      }
    },
    {
      "bounds": {
        "x": 1669,
        "y": 0,
        "width": 831,
        "height": 823
      },
      "action": {
        "type": "postback",
        "text": "優惠資訊",
        "data": "tag=onsale"
      }
    },
    {
      "bounds": {
        "x": 4,
        "y": 822,
        "width": 834,
        "height": 816
      },
      "action": {
        "type": "uri",
        "uri": "line://app/1562278840-mqAaVgA8"
      }
    },
    {
      "bounds": {
        "x": 839,
        "y": 818,
        "width": 826,
        "height": 817
      },
      "action": {
        "type": "postback",
        "text": "聯絡我們",
        "data": "tag=contact_us"
      }
    },
    {
      "bounds": {
        "x": 1700,
        "y": 858,
        "width": 800,
        "height": 810
      },
      "action": {
        "type": "postback",
        "text": "[::text:]more",
        "data": "tag=moreinfo"
      }
    }
  ]
}
"""

# %%
'''

讀取安全檔案內的字串，以供後續程式碼調用

'''
import json
secretFileContentJson=json.load(open("../line_secret_key",'r'))

print(secretFileContentJson.get("channel_access_token"))
print(secretFileContentJson.get("secret_key"))
print(secretFileContentJson.get("self_user_id"))
# Out:
# izJ/0PPUkD2R0Uu79nH2dW6QQ7PxaNmEq34WVRw2z+opNwmCaJDRNk8PTTmT0/Khupwz4DA1bvo+mES40E/fZRZupc1tGerVbX3gZqFPW0un4eFnNWXIG7TSpPCs12Y9DdDJev4uKxyV7YRxgX1nIwdB04t89/1O/w1cDnyilFU=
# 26c156431b38620f168e60393cc6d601
# U2a9289e7bddfbb0db32bcff2547175ef

# %%
'''

將先前準備的菜單設定檔，以Post消息寄發給Line

    設定Line的遠端位置
    設定消息的基本安全憑證
    寄發消息，並取得回應之Id
    

'''

import requests

# menuJson=json.loads(menuRawData)
menuJson2=json.loads(menuRawData2)
menuJson3 = json.loads(Signup)

createMenuEndpoint = 'https://api.line.me/v2/bot/richmenu'
createMenuRequestHeader={'Content-Type':'application/json','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

#print(createMenuRequestHeader)

# lineCreateMenuResponse = requests.post(createMenuEndpoint,headers=createMenuRequestHeader,data=json.dumps(menuJson))
lineCreateMenuResponse2 = requests.post(createMenuEndpoint,headers=createMenuRequestHeader,data=json.dumps(menuJson2))
lineCreateMenuResponse3 = requests.post(createMenuEndpoint,headers=createMenuRequestHeader,data=json.dumps(menuJson3))
# print(lineCreateMenuResponse)
# print(lineCreateMenuResponse.text)
print(lineCreateMenuResponse2)
print(lineCreateMenuResponse2.text)
print(lineCreateMenuResponse3)
print(lineCreateMenuResponse3.text)
# Out:
# <Response [200]>
# {"richMenuId":"richmenu-53489ca3159450d0aa47e347ac7d7239"}
# <Response [200]>
# {"richMenuId":"richmenu-43039ab192605952354a1db28a43b777"}

# %%
'''

將先前準備的菜單照片，以Post消息寄發給Line
    取得上面設定檔的Id
    設定Line的遠端位置
    設定消息的基本安全憑證
    上傳照片，並取得回傳成果

'''

# 取得菜單Id 
# uploadRichMenuId=json.loads(lineCreateMenuResponse.text).get("richMenuId")
uploadRichMenuId2=json.loads(lineCreateMenuResponse2.text).get("richMenuId")
uploadRichMenuId3=json.loads(lineCreateMenuResponse3.text).get("richMenuId")
# print(uploadRichMenuId)
print(uploadRichMenuId2)
print(uploadRichMenuId3)
#'https://api.line.me/v2/bot/richmenu/{richMenuId}/content'

# 設定Line的遠端位置
# uploadMenuEndpoint='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId
uploadMenuEndpoint2='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId2
uploadMenuEndpoint3='https://api.line.me/v2/bot/richmenu/%s/content' % uploadRichMenuId3
# print(uploadMenuEndpoint)
print(uploadMenuEndpoint2)
print(uploadMenuEndpoint3)


# 設定消息的基本安全憑證
uploadMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 上傳照片
# uploadImageFile=open("../images/functional_menu_test5.jpg",'rb')
uploadImageFile2=open("../images/functional_menu_user2.jpg",'rb')
uploadImageFile3=open("../images/signup2.jpg",'rb')
# lineUploadMenuResponse=requests.post(uploadMenuEndpoint,headers=uploadMenuRequestHeader,data=uploadImageFile)
lineUploadMenuResponse2=requests.post(uploadMenuEndpoint2,headers=uploadMenuRequestHeader,data=uploadImageFile2)
lineUploadMenuResponse3=requests.post(uploadMenuEndpoint3,headers=uploadMenuRequestHeader,data=uploadImageFile3)
# print(lineUploadMenuResponse)
# print(lineUploadMenuResponse.text)
print(lineUploadMenuResponse2)
print(lineUploadMenuResponse2.text)
print(lineUploadMenuResponse3)
print(lineUploadMenuResponse3.text)
# Out:
# richmenu-53489ca3159450d0aa47e347ac7d7239
# richmenu-43039ab192605952354a1db28a43b777
# https://api.line.me/v2/bot/richmenu/richmenu-53489ca3159450d0aa47e347ac7d7239/content
# https://api.line.me/v2/bot/richmenu/richmenu-43039ab192605952354a1db28a43b777/content
# <Response [200]>
# {}
# <Response [200]>
# {}

# %%
'''

將選單綁定到特定用戶身上
    取出上面得到的菜單Id及用戶id
    設定Line的遠端位置
    設定消息的基本安全憑證
    發送消息告知

'''

# https://api.line.me/v2/bot/user/{userId}/richmenu/{richMenuId}

# 取得菜單id
# linkRichMenuId=json.loads(lineCreateMenuResponse.text).get("richMenuId")
linkRichMenuId2=json.loads(lineCreateMenuResponse2.text).get("richMenuId")
linkRichMenuId3=json.loads(lineCreateMenuResponse3.text).get("richMenuId")

# query mysql user_id
user_id = 2
query = [0, 1]

# 將菜單id與用戶id組合成遠端位置
if user_id in query:
    linkMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu/%s' % (secretFileContentJson["self_user_id"], linkRichMenuId2)
else:
    linkMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu/%s' % (secretFileContentJson["self_user_id"], linkRichMenuId3)
print(linkMenuEndpoint)

# 設定消息基本安全憑證
linkMenuRequestHeader={'Content-Type':'image/jpeg','Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 發送消息
lineLinkMenuResponse=requests.post(linkMenuEndpoint,headers=linkMenuRequestHeader)
print(lineLinkMenuResponse)
print(lineLinkMenuResponse.text)
# Out:
# https://api.line.me/v2/bot/user/U2a9289e7bddfbb0db32bcff2547175ef/richmenu/richmenu-43039ab192605952354a1db28a43b777
# <Response [200]>
# {}

# %%
'''

檢視用戶目前所綁定的菜單
    取出用戶id
    設定Line的遠端位置
    設定消息的基本安全憑證
    發送消息告知

'''

#  https://api.line.me/v2/bot/user/{userId}/richmenu

# 取出用戶id，設定Line的遠端位置
userMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu' % (secretFileContentJson["self_user_id"])
print(userMenuEndpoint)

# 設定消息的基本安全憑證
userMenuRequestHeader={'Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 發送消息告知
lineUserMenuResponse=requests.get(userMenuEndpoint,headers=userMenuRequestHeader)
print(lineUserMenuResponse)
print(lineUserMenuResponse.text)
# Out:
# https://api.line.me/v2/bot/user/U2a9289e7bddfbb0db32bcff2547175ef/richmenu
# <Response [200]>
# {"richMenuId":"richmenu-43039ab192605952354a1db28a43b777"}

# %%
'''

解除選單與特定用戶的綁定
    取出用戶id
    設定Line的遠端位置
    設定消息的基本安全憑證
    發送消息告知

'''

# 取出用戶id，設定Line的遠端位置
userMenuEndpoint='https://api.line.me/v2/bot/user/%s/richmenu' % (secretFileContentJson["self_user_id"])
print(userMenuEndpoint)

# 設定消息的基本安全憑證
userMenuRequestHeader={'Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}

# 發送消息告知
lineUnregisterUserMenuResponse=requests.delete(userMenuEndpoint,headers=userMenuRequestHeader)
print(lineUnregisterUserMenuResponse)
print(lineUnregisterUserMenuResponse.text)
# Out:
# https://api.line.me/v2/bot/user/U2a9289e7bddfbb0db32bcff2547175ef/richmenu
# <Response [200]>
# {}

# %%
'''

檢視帳號內，有哪些選單
    設定Line的遠端位置
    設定消息的基本安全憑證
    發送消息告知

'''

# 設定Line的遠端位置
listMenuEndpoint="https://api.line.me/v2/bot/richmenu/list"

# 設定消息的基本安全憑證
listMenuHeader={'Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}    

# 發送消息告知
lineLisrMenuResponse = requests.get(listMenuEndpoint,headers=listMenuHeader)
print(lineLisrMenuResponse.text)
# Out:
# {"richmenus":[{"richMenuId":"richmenu-d421a877771377121a877a8fb4bb94c4","name":"圖文選單 1","size":{"width":2500,"height":1686},"chatBarText":"查看更多資訊","selected":true,"areas":[{"bounds":{"x":0,"y":0,"width":839,"height":818},"action":{"type":"postback","data":"tag=userprofile","text":"會員資料"}},{"bounds":{"x":835,"y":4,"width":830,"height":818},"action":{"type":"postback","data":"tag=shopinfo","text":"門市資訊"}},{"bounds":{"x":1669,"y":0,"width":831,"height":823},"action":{"type":"postback","data":"tag=onsale","text":"優惠資訊"}},{"bounds":{"x":4,"y":822,"width":834,"height":816},"action":{"type":"uri","uri":"line://app/1562278840-mqAaVgA8"}},{"bounds":{"x":839,"y":818,"width":826,"height":817},"action":{"type":"postback","data":"tag=contact_us","text":"聯絡我們"}},{"bounds":{"x":1700,"y":858,"width":800,"height":810},"action":{"type":"postback","data":"tag=moreinfo","text":"[::text:]more"}}]}]}

# %%
"""
刪除單個
"""

listMenuHeader={'Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]} 
requests.delete("https://api.line.me/v2/bot/richmenu/richmenu-aab2649a065db4b829ef02d9a70267c6", headers=listMenuHeader)
# Out:
# <Response [200]>

# %%
"""
刪除所有richmenu
"""
# 設定Line的遠端位置
listMenuEndpoint="https://api.line.me/v2/bot/richmenu/list"

# 設定消息的基本安全憑證
listMenuHeader={'Authorization':'Bearer %s' % secretFileContentJson["channel_access_token"]}    

# 發送消息告知
lineLisrMenuResponse = requests.get(listMenuEndpoint,headers=listMenuHeader)
# print(lineLisrMenuResponse.text)
L1 = json.loads(lineLisrMenuResponse.text)
ri = L1["richmenus"]
for r in ri:
    rr = r["richMenuId"]
    requests.delete("https://api.line.me/v2/bot/richmenu/%s" % rr, headers=listMenuHeader)
